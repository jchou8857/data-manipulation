# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

baltimore = pd.read_csv('C:/Users/JChou/Desktop/Women+/17. Data Manipulation/17.3 Studio/dataset/baltimore_9-24-2016_9-30-2017.csv')
boston = pd.read_csv('C:/Users/JChou/Desktop/Women+/17. Data Manipulation/17.3 Studio/dataset/boston_9-24-2016_9-30-2017.csv')
new_york = pd.read_csv('C:/Users/JChou/Desktop/Women+/17. Data Manipulation/17.3 Studio/dataset/new-york_9-24-2016_9-30-2017.csv')
philadelphia = pd.read_csv('C:/Users/JChou/Desktop/Women+/17. Data Manipulation/17.3 Studio/dataset/philadelphia_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in boston.columns:
    pct_missing = np.mean(boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in new_york.columns:
    pct_missing = np.mean(new_york[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in philadelphia.columns:
    pct_missing = np.mean(philadelphia[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))# Clean your data here!
for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in boston.columns:
    pct_missing = np.mean(boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in new_york.columns:
    pct_missing = np.mean(new_york[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
print('\n')
for col in philadelphia.columns:
    pct_missing = np.mean(philadelphia[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
baltimore_dropped = baltimore.drop(['Commodity Name', 'Type', 'Grade', 'Origin District', 'Environment', 'Quality','Condition','Appearance','Storage','Crop','Repack','Trans Mode','Mostly Low', 'Mostly High'], axis=1)
boston_dropped = boston.drop(['Commodity Name', 'Type', 'Grade', 'Origin District', 'Environment', 'Quality','Condition','Appearance','Storage','Crop','Repack','Trans Mode','Mostly Low', 'Mostly High'], axis=1)
new_york_dropped = new_york.drop(['Commodity Name', 'Type', 'Grade', 'Origin District', 'Environment', 'Quality','Condition','Appearance','Storage','Crop','Repack','Trans Mode','Mostly Low', 'Mostly High'], axis=1)
philadelphia_dropped = philadelphia.drop(['Commodity Name', 'Type', 'Grade', 'Origin District', 'Environment', 'Quality','Condition','Appearance','Storage','Crop','Repack','Trans Mode','Mostly Low', 'Mostly High'], axis=1)
# Out:
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 1.0%
# Sub Variety - 84.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 3.0%
# Origin District - 100.0%
# Item Size - 16.0%
# Color - 80.0%
# Environment - 100.0%
# Unit of Sale - 84.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 92.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 81.0%
# Item Size - 1.0%
# Color - 14.0%
# Environment - 100.0%
# Unit of Sale - 87.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 84.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 87.0%
# Item Size - 7.0%
# Color - 81.0%
# Environment - 100.0%
# Unit of Sale - 78.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 79.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 100.0%
# Item Size - 21.0%
# Color - 100.0%
# Environment - 100.0%
# Unit of Sale - 81.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 1.0%
# Sub Variety - 84.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 3.0%
# Origin District - 100.0%
# Item Size - 16.0%
# Color - 80.0%
# Environment - 100.0%
# Unit of Sale - 84.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 92.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 81.0%
# Item Size - 1.0%
# Color - 14.0%
# Environment - 100.0%
# Unit of Sale - 87.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 84.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 87.0%
# Item Size - 7.0%
# Color - 81.0%
# Environment - 100.0%
# Unit of Sale - 78.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%
#
#
# Commodity Name - 0.0%
# City Name - 0.0%
# Type - 100.0%
# Package - 0.0%
# Variety - 0.0%
# Sub Variety - 79.0%
# Grade - 100.0%
# Date - 0.0%
# Low Price - 0.0%
# High Price - 0.0%
# Mostly Low - 0.0%
# Mostly High - 0.0%
# Origin - 0.0%
# Origin District - 100.0%
# Item Size - 21.0%
# Color - 100.0%
# Environment - 100.0%
# Unit of Sale - 81.0%
# Quality - 100.0%
# Condition - 100.0%
# Appearance - 100.0%
# Storage - 100.0%
# Crop - 100.0%
# Repack - 0.0%
# Trans Mode - 100.0%

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
northeast = pd.concat([baltimore_dropped, boston_dropped, new_york_dropped, philadelphia_dropped])
northeast
# Out:
#        City Name               Package            Variety Sub Variety  \
# 0      BALTIMORE          24 inch bins                NaN         NaN
# 1      BALTIMORE          24 inch bins                NaN         NaN
# 2      BALTIMORE          24 inch bins        HOWDEN TYPE         NaN
# 3      BALTIMORE          24 inch bins        HOWDEN TYPE         NaN
# 4      BALTIMORE          24 inch bins        HOWDEN TYPE         NaN
# 5      BALTIMORE          24 inch bins        HOWDEN TYPE         NaN
# 6      BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 7      BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 8      BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 9      BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 10     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 11     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 12     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 13     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 14     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 15     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 16     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 17     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 18     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 19     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 20     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 21     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 22     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 23     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 24     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 25     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 26     BALTIMORE          36 inch bins        HOWDEN TYPE         NaN
# 27     BALTIMORE          24 inch bins  HOWDEN WHITE TYPE         NaN
# 28     BALTIMORE          24 inch bins  HOWDEN WHITE TYPE         NaN
# 29     BALTIMORE          24 inch bins         CINDERELLA         NaN
# ..           ...                   ...                ...         ...
# 27  PHILADELPHIA          36 inch bins        HOWDEN TYPE         NaN
# 28  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 29  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 30  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 31  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 32  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 33  PHILADELPHIA  1 1/9 bushel cartons           PIE TYPE         NaN
# 34  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 35  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 36  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 37  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 38  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 39  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 40  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 41  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 42  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 43  PHILADELPHIA          24 inch bins           PIE TYPE         NaN
# 44  PHILADELPHIA          24 inch bins       KNUCKLE HEAD         NaN
# 45  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 46  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 47  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 48  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 49  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 50  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 51  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 52  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 53  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 54  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 55  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
# 56  PHILADELPHIA    1/2 bushel cartons          MINIATURE   FLAT TYPE
#
#           Date  Low Price  High Price        Origin Item Size   Color  \
# 0   04/29/2017        270       280.0           NaN       lge     NaN
# 1   05/06/2017        270       280.0           NaN       lge     NaN
# 2   09/24/2016        160       160.0      DELAWARE       med     NaN
# 3   09/24/2016        160       160.0      VIRGINIA       med     NaN
# 4   11/05/2016         90       100.0      MARYLAND       lge     NaN
# 5   11/12/2016         90       100.0      MARYLAND       lge     NaN
# 6   09/24/2016        160       170.0      MARYLAND       med     NaN
# 7   09/24/2016        160       160.0  PENNSYLVANIA       lge     NaN
# 8   10/01/2016        160       170.0      MARYLAND       med     NaN
# 9   10/01/2016        160       160.0  PENNSYLVANIA       lge     NaN
# 10  10/08/2016        160       170.0      MARYLAND       med     NaN
# 11  10/08/2016        160       160.0  PENNSYLVANIA       lge     NaN
# 12  10/15/2016        150       160.0      MARYLAND       lge     NaN
# 13  10/15/2016        150       170.0      MARYLAND       med     NaN
# 14  10/22/2016        150       160.0      MARYLAND       lge     NaN
# 15  10/22/2016        140       160.0      MARYLAND       med     NaN
# 16  10/29/2016        100       160.0      MARYLAND       lge     NaN
# 17  10/29/2016        130       160.0      MARYLAND       med     NaN
# 18  10/29/2016        130       130.0      MARYLAND       sml     NaN
# 19  11/05/2016        120       130.0      MARYLAND      xlge     NaN
# 20  11/05/2016        100       130.0      MARYLAND       lge     NaN
# 21  11/05/2016         90       100.0      MARYLAND       med     NaN
# 22  11/12/2016        100       120.0      MARYLAND       lge     NaN
# 23  09/16/2017        160       160.0      MARYLAND   med-lge  ORANGE
# 24  09/23/2017        160       160.0      MARYLAND   med-lge  ORANGE
# 25  09/30/2017        150       160.0      MARYLAND       lge  ORANGE
# 26  09/30/2017        150       160.0      MARYLAND   med-lge  ORANGE
# 27  09/23/2017        160       180.0      MARYLAND       med     NaN
# 28  09/30/2017        180       180.0      MARYLAND       med     NaN
# 29  06/03/2017        380       380.0           NaN      xlge     NaN
# ..         ...        ...         ...           ...       ...     ...
# 27  09/30/2017        140       140.0      DELAWARE       med     NaN
# 28  10/15/2016         12        14.0          OHIO       med     NaN
# 29  10/22/2016         12        12.0          OHIO       med     NaN
# 30  10/29/2016         12        12.0          OHIO       med     NaN
# 31  08/26/2017         18        20.0      MICHIGAN       med     NaN
# 32  09/16/2017         18        18.0          OHIO       med     NaN
# 33  09/23/2017         18        22.0          OHIO       med     NaN
# 34  10/01/2016        250       250.0  PENNSYLVANIA       med     NaN
# 35  10/15/2016        140       140.0  PENNSYLVANIA       med     NaN
# 36  10/22/2016        140       150.0  PENNSYLVANIA       med     NaN
# 37  10/22/2016         75       100.0  PENNSYLVANIA       sml     NaN
# 38  10/29/2016        140       150.0  PENNSYLVANIA       med     NaN
# 39  10/29/2016         75       100.0  PENNSYLVANIA       sml     NaN
# 40  09/23/2017        180       180.0      DELAWARE       med     NaN
# 41  09/23/2017        140       140.0      DELAWARE       sml     NaN
# 42  09/23/2017        180       180.0      NEW YORK       med     NaN
# 43  09/30/2017        140       140.0      DELAWARE       sml     NaN
# 44  10/08/2016        210       210.0    NEW JERSEY       med     NaN
# 45  09/24/2016         17        18.0          OHIO       NaN     NaN
# 46  10/01/2016         18        18.0    NEW JERSEY       NaN     NaN
# 47  10/01/2016         17        18.0          OHIO       NaN     NaN
# 48  10/08/2016         15        15.0          OHIO       NaN     NaN
# 49  10/15/2016         15        18.0          OHIO       NaN     NaN
# 50  10/22/2016         16        18.0          OHIO       NaN     NaN
# 51  10/29/2016         16        18.0          OHIO       NaN     NaN
# 52  11/05/2016         16        18.0          OHIO       NaN     NaN
# 53  08/26/2017         18        20.0      MICHIGAN       NaN     NaN
# 54  09/16/2017         16        16.0          OHIO       NaN     NaN
# 55  09/23/2017         15        16.0          OHIO       NaN     NaN
# 56  09/30/2017         15        18.0          OHIO       NaN     NaN
#
#    Unit of Sale
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45   SHELLACKED
# 46          NaN
# 47   SHELLACKED
# 48   SHELLACKED
# 49   SHELLACKED
# 50   SHELLACKED
# 51   SHELLACKED
# 52   SHELLACKED
# 53   SHELLACKED
# 54   SHELLACKED
# 55   SHELLACKED
# 56   SHELLACKED
#
# [674 rows x 11 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
northeast_unitofsale_groupby = northeast.groupby('Unit of Sale').agg('mean')
northeast_unitofsale_groupby
# Out:
#                Low Price  High Price
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
northeast_variety_groupby = northeast.groupby('Variety').agg('mean')
northeast_variety_groupby
# Out:
#                            Low Price  High Price
# Variety
# BIG MACK TYPE             129.454545  147.272727
# BLUE TYPE                 260.000000  285.000000
# CINDERELLA                206.051282  220.974359
# FAIRYTALE                 198.783784  214.108108
# HOWDEN TYPE               152.834821  177.098214
# HOWDEN WHITE TYPE         170.000000  180.000000
# KNUCKLE HEAD              238.888889  260.555556
# MINIATURE                  16.391753   17.886598
# MIXED HEIRLOOM VARIETIES  210.000000  230.000000
# PIE TYPE                  133.404040  148.118687

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
